# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# len(coordinates)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify nearest city for each latitude and longitude combination
for lat_lng in coordinates:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %%
# cities

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4367bcaf1368275cecb0fbab3bc76fc0

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
from pprint import pprint

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
# for i in range(len(cities)):

#     # Group cities in sets of 50 for logging purposes.
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#     # Create endpoint URL with each city.
#     city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
#         pprint(city_weather)
#         break
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tasiilaq
# Processing Record 2 of Set 1 | chukhloma
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | isangel
# Processing Record 6 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 1 | cidreira
# Processing Record 9 of Set 1 | chuka
# Processing Record 10 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 1 | geraldton
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | toora-khem
# Processing Record 14 of Set 1 | conceicao do araguaia
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | lagoa
# Processing Record 17 of Set 1 | kyabe
# Processing Record 18 of Set 1 | east london
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | khatanga
# Processing Record 21 of Set 1 | kodiak
# Processing Record 22 of Set 1 | bengkulu
# Processing Record 23 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 1 | solsvik
# City not found. Skipping...
# Processing Record 25 of Set 1 | coffs harbour
# Processing Record 26 of Set 1 | fortuna
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | anar darreh
# City not found. Skipping...
# Processing Record 29 of Set 1 | yicheng
# Processing Record 30 of Set 1 | longyearbyen
# Processing Record 31 of Set 1 | cabo san lucas
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | esperance
# Processing Record 34 of Set 1 | high rock
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | novo oriente
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | chuy
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | raudeberg
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | lubango
# Processing Record 47 of Set 1 | chapais
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | faya
# Processing Record 50 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 2 | sorland
# Processing Record 2 of Set 2 | vila franca do campo
# Processing Record 3 of Set 2 | uruzgan
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 2 | lebu
# Processing Record 7 of Set 2 | saskylakh
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | mahebourg
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | guerrero negro
# Processing Record 12 of Set 2 | kununurra
# Processing Record 13 of Set 2 | ahvaz
# Processing Record 14 of Set 2 | port elizabeth
# Processing Record 15 of Set 2 | narsaq
# Processing Record 16 of Set 2 | sao filipe
# Processing Record 17 of Set 2 | cassilandia
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | chokurdakh
# Processing Record 20 of Set 2 | castro
# Processing Record 21 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 2 | iqaluit
# Processing Record 23 of Set 2 | rikitea
# Processing Record 24 of Set 2 | pisco
# Processing Record 25 of Set 2 | tezu
# Processing Record 26 of Set 2 | labuhan
# Processing Record 27 of Set 2 | mayo
# Processing Record 28 of Set 2 | sitka
# Processing Record 29 of Set 2 | coaldale
# Processing Record 30 of Set 2 | cherskiy
# Processing Record 31 of Set 2 | thompson
# Processing Record 32 of Set 2 | ambunti
# Processing Record 33 of Set 2 | caluquembe
# Processing Record 34 of Set 2 | riyadh
# Processing Record 35 of Set 2 | rajpur
# Processing Record 36 of Set 2 | tambun
# Processing Record 37 of Set 2 | hithadhoo
# Processing Record 38 of Set 2 | sinnamary
# Processing Record 39 of Set 2 | priverno
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | souillac
# Processing Record 42 of Set 2 | natal
# Processing Record 43 of Set 2 | agaro
# Processing Record 44 of Set 2 | saint-pierre
# Processing Record 45 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | prince rupert
# Processing Record 48 of Set 2 | port blair
# Processing Record 49 of Set 2 | batavia
# Processing Record 50 of Set 2 | provideniya
# Processing Record 1 of Set 3 | mar del plata
# Processing Record 2 of Set 3 | atuona
# Processing Record 3 of Set 3 | bathsheba
# Processing Record 4 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 3 | bethel
# Processing Record 6 of Set 3 | faanui
# Processing Record 7 of Set 3 | atar
# Processing Record 8 of Set 3 | gobabis
# Processing Record 9 of Set 3 | pevek
# Processing Record 10 of Set 3 | georgetown
# Processing Record 11 of Set 3 | lata
# Processing Record 12 of Set 3 | ribeira grande
# Processing Record 13 of Set 3 | ode
# Processing Record 14 of Set 3 | manado
# Processing Record 15 of Set 3 | kavaratti
# Processing Record 16 of Set 3 | adrar
# Processing Record 17 of Set 3 | avarua
# Processing Record 18 of Set 3 | bredasdorp
# Processing Record 19 of Set 3 | boueni
# Processing Record 20 of Set 3 | dubenskiy
# City not found. Skipping...
# Processing Record 21 of Set 3 | port hueneme
# Processing Record 22 of Set 3 | abrau-dyurso
# Processing Record 23 of Set 3 | ginda
# Processing Record 24 of Set 3 | yankton
# Processing Record 25 of Set 3 | roma
# Processing Record 26 of Set 3 | saint-philippe
# Processing Record 27 of Set 3 | half moon bay
# Processing Record 28 of Set 3 | touros
# Processing Record 29 of Set 3 | helong
# Processing Record 30 of Set 3 | olafsvik
# Processing Record 31 of Set 3 | grindavik
# Processing Record 32 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 33 of Set 3 | camopi
# Processing Record 34 of Set 3 | gamba
# Processing Record 35 of Set 3 | upernavik
# Processing Record 36 of Set 3 | saint george
# Processing Record 37 of Set 3 | talnakh
# Processing Record 38 of Set 3 | eureka
# Processing Record 39 of Set 3 | balikpapan
# Processing Record 40 of Set 3 | new norfolk
# Processing Record 41 of Set 3 | nikolskoye
# Processing Record 42 of Set 3 | leshukonskoye
# Processing Record 43 of Set 3 | vestmannaeyjar
# Processing Record 44 of Set 3 | muros
# Processing Record 45 of Set 3 | te anau
# Processing Record 46 of Set 3 | cazaje
# City not found. Skipping...
# Processing Record 47 of Set 3 | los llanos de aridane
# Processing Record 48 of Set 3 | laguna
# Processing Record 49 of Set 3 | san ramon
# Processing Record 50 of Set 3 | bani walid
# Processing Record 1 of Set 4 | gboko
# Processing Record 2 of Set 4 | victoria
# Processing Record 3 of Set 4 | coihaique
# Processing Record 4 of Set 4 | cururupu
# Processing Record 5 of Set 4 | broken hill
# Processing Record 6 of Set 4 | kutum
# Processing Record 7 of Set 4 | guajara
# Processing Record 8 of Set 4 | chicama
# Processing Record 9 of Set 4 | maceio
# Processing Record 10 of Set 4 | jiangyou
# Processing Record 11 of Set 4 | nishihara
# Processing Record 12 of Set 4 | limon
# Processing Record 13 of Set 4 | landang
# City not found. Skipping...
# Processing Record 14 of Set 4 | buin
# Processing Record 15 of Set 4 | ponta do sol
# Processing Record 16 of Set 4 | ancud
# Processing Record 17 of Set 4 | terralba
# Processing Record 18 of Set 4 | mareeba
# Processing Record 19 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 4 | nouakchott
# Processing Record 21 of Set 4 | willowmore
# Processing Record 22 of Set 4 | alenquer
# Processing Record 23 of Set 4 | isilkul
# Processing Record 24 of Set 4 | benjamin hill
# Processing Record 25 of Set 4 | lompoc
# Processing Record 26 of Set 4 | changping
# Processing Record 27 of Set 4 | vostok
# Processing Record 28 of Set 4 | ahuimanu
# Processing Record 29 of Set 4 | ashqelon
# Processing Record 30 of Set 4 | kaitangata
# Processing Record 31 of Set 4 | sao jose da coroa grande
# Processing Record 32 of Set 4 | dourados
# Processing Record 33 of Set 4 | beringovskiy
# Processing Record 34 of Set 4 | moa
# Processing Record 35 of Set 4 | cootamundra
# Processing Record 36 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 4 | port lincoln
# Processing Record 38 of Set 4 | yoichi
# Processing Record 39 of Set 4 | naze
# Processing Record 40 of Set 4 | wanning
# Processing Record 41 of Set 4 | sabang
# Processing Record 42 of Set 4 | clyde river
# Processing Record 43 of Set 4 | upington
# Processing Record 44 of Set 4 | burica
# City not found. Skipping...
# Processing Record 45 of Set 4 | povenets
# Processing Record 46 of Set 4 | beyneu
# Processing Record 47 of Set 4 | heihe
# Processing Record 48 of Set 4 | atasu
# Processing Record 49 of Set 4 | severo-kurilsk
# Processing Record 50 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 5 | kaeo
# Processing Record 2 of Set 5 | agvali
# Processing Record 3 of Set 5 | port augusta
# Processing Record 4 of Set 5 | caravelas
# Processing Record 5 of Set 5 | vallenar
# Processing Record 6 of Set 5 | cockburn town
# Processing Record 7 of Set 5 | hermanus
# Processing Record 8 of Set 5 | tilichiki
# Processing Record 9 of Set 5 | korla
# Processing Record 10 of Set 5 | san felipe
# Processing Record 11 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 5 | norman wells
# Processing Record 13 of Set 5 | berlevag
# Processing Record 14 of Set 5 | asau
# Processing Record 15 of Set 5 | raton
# Processing Record 16 of Set 5 | herat
# Processing Record 17 of Set 5 | cabedelo
# Processing Record 18 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 5 | idar
# Processing Record 20 of Set 5 | puerto baquerizo moreno
# Processing Record 21 of Set 5 | waverly
# Processing Record 22 of Set 5 | causapscal
# Processing Record 23 of Set 5 | tiksi
# Processing Record 24 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 5 | armidale
# Processing Record 26 of Set 5 | vila velha
# Processing Record 27 of Set 5 | ondjiva
# Processing Record 28 of Set 5 | solnechnyy
# Processing Record 29 of Set 5 | xiaoweizhai
# Processing Record 30 of Set 5 | gat
# Processing Record 31 of Set 5 | ostrovnoy
# Processing Record 32 of Set 5 | beloha
# Processing Record 33 of Set 5 | poya
# Processing Record 34 of Set 5 | parchim
# Processing Record 35 of Set 5 | zaozerne
# Processing Record 36 of Set 5 | paamiut
# Processing Record 37 of Set 5 | sao joao da barra
# Processing Record 38 of Set 5 | klaksvik
# Processing Record 39 of Set 5 | athabasca
# Processing Record 40 of Set 5 | yerofey pavlovich
# Processing Record 41 of Set 5 | padang
# Processing Record 42 of Set 5 | arlit
# Processing Record 43 of Set 5 | saint anthony
# Processing Record 44 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 45 of Set 5 | lipari
# Processing Record 46 of Set 5 | sfantu gheorghe
# Processing Record 47 of Set 5 | yenagoa
# Processing Record 48 of Set 5 | coquimbo
# Processing Record 49 of Set 5 | saurimo
# Processing Record 50 of Set 5 | the valley
# Processing Record 1 of Set 6 | ugoofaaru
# Processing Record 2 of Set 6 | huimilpan
# Processing Record 3 of Set 6 | mazatlan
# Processing Record 4 of Set 6 | wewak
# Processing Record 5 of Set 6 | shilovo
# Processing Record 6 of Set 6 | russell
# Processing Record 7 of Set 6 | ihosy
# Processing Record 8 of Set 6 | bambous virieux
# Processing Record 9 of Set 6 | bubaque
# Processing Record 10 of Set 6 | axim
# Processing Record 11 of Set 6 | high level
# Processing Record 12 of Set 6 | henties bay
# Processing Record 13 of Set 6 | uarini
# Processing Record 14 of Set 6 | porto walter
# Processing Record 15 of Set 6 | zhukovka
# Processing Record 16 of Set 6 | kruisfontein
# Processing Record 17 of Set 6 | khandyga
# Processing Record 18 of Set 6 | lavrentiya
# Processing Record 19 of Set 6 | pauri
# Processing Record 20 of Set 6 | ulaanbaatar
# Processing Record 21 of Set 6 | saldanha
# Processing Record 22 of Set 6 | nanortalik
# Processing Record 23 of Set 6 | ilulissat
# Processing Record 24 of Set 6 | wangqing
# Processing Record 25 of Set 6 | kamaishi
# Processing Record 26 of Set 6 | aloleng
# Processing Record 27 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 6 | road town
# Processing Record 30 of Set 6 | college
# Processing Record 31 of Set 6 | cabra
# Processing Record 32 of Set 6 | ritchie
# Processing Record 33 of Set 6 | iskateley
# Processing Record 34 of Set 6 | port dover
# Processing Record 35 of Set 6 | bonavista
# Processing Record 36 of Set 6 | rawlins
# Processing Record 37 of Set 6 | hambantota
# Processing Record 38 of Set 6 | maniitsoq
# Processing Record 39 of Set 6 | grand-santi
# Processing Record 40 of Set 6 | srednekolymsk
# Processing Record 41 of Set 6 | nushki
# Processing Record 42 of Set 6 | anchorage
# Processing Record 43 of Set 6 | portree
# Processing Record 44 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 6 | pulsano
# Processing Record 46 of Set 6 | miguel hidalgo
# Processing Record 47 of Set 6 | haines junction
# Processing Record 48 of Set 6 | tawang
# Processing Record 49 of Set 6 | la union
# Processing Record 50 of Set 6 | tabulbah
# City not found. Skipping...
# Processing Record 1 of Set 7 | ust-karsk
# Processing Record 2 of Set 7 | puri
# Processing Record 3 of Set 7 | syracuse
# Processing Record 4 of Set 7 | kirksville
# Processing Record 5 of Set 7 | chakan
# Processing Record 6 of Set 7 | maumere
# Processing Record 7 of Set 7 | sambava
# Processing Record 8 of Set 7 | wagga wagga
# Processing Record 9 of Set 7 | hay river
# Processing Record 10 of Set 7 | kavieng
# Processing Record 11 of Set 7 | north platte
# Processing Record 12 of Set 7 | sieradz
# Processing Record 13 of Set 7 | santa luzia
# Processing Record 14 of Set 7 | hervey bay
# Processing Record 15 of Set 7 | zeya
# Processing Record 16 of Set 7 | ndele
# Processing Record 17 of Set 7 | torbay
# Processing Record 18 of Set 7 | gwanda
# Processing Record 19 of Set 7 | hofn
# Processing Record 20 of Set 7 | bosaso
# Processing Record 21 of Set 7 | akureyri
# Processing Record 22 of Set 7 | mandera
# Processing Record 23 of Set 7 | banjar
# Processing Record 24 of Set 7 | monrovia
# Processing Record 25 of Set 7 | bambanglipuro
# Processing Record 26 of Set 7 | murdochville
# Processing Record 27 of Set 7 | birobidzhan
# Processing Record 28 of Set 7 | veraval
# Processing Record 29 of Set 7 | taoudenni
# Processing Record 30 of Set 7 | talara
# Processing Record 31 of Set 7 | dubbo
# Processing Record 32 of Set 7 | mufulira
# Processing Record 33 of Set 7 | aklavik
# Processing Record 34 of Set 7 | morondava
# Processing Record 35 of Set 7 | jadu
# Processing Record 36 of Set 7 | gorontalo
# Processing Record 37 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 7 | bonthe
# Processing Record 39 of Set 7 | moskovskiy
# Processing Record 40 of Set 7 | gisborne
# Processing Record 41 of Set 7 | mujiayingzi
# Processing Record 42 of Set 7 | buraydah
# Processing Record 43 of Set 7 | selma
# Processing Record 44 of Set 7 | tortoli
# Processing Record 45 of Set 7 | ascoli piceno
# Processing Record 46 of Set 7 | camacha
# Processing Record 47 of Set 7 | ahipara
# Processing Record 48 of Set 7 | aksu
# Processing Record 49 of Set 7 | bay-khaak
# Processing Record 50 of Set 7 | townsville
# Processing Record 1 of Set 8 | muroto
# Processing Record 2 of Set 8 | gurupi
# Processing Record 3 of Set 8 | kharan
# Processing Record 4 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 5 of Set 8 | camargo
# Processing Record 6 of Set 8 | caxito
# Processing Record 7 of Set 8 | pangnirtung
# Processing Record 8 of Set 8 | roald
# Processing Record 9 of Set 8 | bandarbeyla
# Processing Record 10 of Set 8 | maine-soroa
# Processing Record 11 of Set 8 | edd
# Processing Record 12 of Set 8 | livingston
# Processing Record 13 of Set 8 | hasaki
# Processing Record 14 of Set 8 | galiakot
# Processing Record 15 of Set 8 | pilar
# Processing Record 16 of Set 8 | carnarvon
# Processing Record 17 of Set 8 | atka
# City not found. Skipping...
# Processing Record 18 of Set 8 | pandan
# Processing Record 19 of Set 8 | la vista
# Processing Record 20 of Set 8 | changli
# Processing Record 21 of Set 8 | karratha
# Processing Record 22 of Set 8 | nuuk
# Processing Record 23 of Set 8 | nemuro
# Processing Record 24 of Set 8 | magadan
# Processing Record 25 of Set 8 | mineiros
# Processing Record 26 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 27 of Set 8 | keetmanshoop
# Processing Record 28 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 29 of Set 8 | olinda
# Processing Record 30 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 8 | evensk
# Processing Record 32 of Set 8 | diamantino
# Processing Record 33 of Set 8 | calmar
# Processing Record 34 of Set 8 | puerto penasco
# Processing Record 35 of Set 8 | yar-sale
# Processing Record 36 of Set 8 | kemijarvi
# Processing Record 37 of Set 8 | cholet
# Processing Record 38 of Set 8 | salalah
# Processing Record 39 of Set 8 | bartica
# Processing Record 40 of Set 8 | airai
# Processing Record 41 of Set 8 | barra da estiva
# Processing Record 42 of Set 8 | san quintin
# Processing Record 43 of Set 8 | constitucion
# Processing Record 44 of Set 8 | viedma
# Processing Record 45 of Set 8 | koshurnikovo
# Processing Record 46 of Set 8 | tuntum
# Processing Record 47 of Set 8 | souris
# Processing Record 48 of Set 8 | zhangye
# Processing Record 49 of Set 8 | boa vista
# Processing Record 50 of Set 8 | kerrville
# Processing Record 1 of Set 9 | soyo
# Processing Record 2 of Set 9 | karasjok
# Processing Record 3 of Set 9 | belaya gora
# Processing Record 4 of Set 9 | havre-saint-pierre
# Processing Record 5 of Set 9 | vitim
# Processing Record 6 of Set 9 | lasa
# Processing Record 7 of Set 9 | harper
# Processing Record 8 of Set 9 | baillif
# Processing Record 9 of Set 9 | husavik
# Processing Record 10 of Set 9 | lander
# Processing Record 11 of Set 9 | vila
# Processing Record 12 of Set 9 | calabar
# Processing Record 13 of Set 9 | ganzhou
# Processing Record 14 of Set 9 | pontes e lacerda
# Processing Record 15 of Set 9 | babakan
# Processing Record 16 of Set 9 | shimoda
# Processing Record 17 of Set 9 | tahlequah
# Processing Record 18 of Set 9 | omboue
# Processing Record 19 of Set 9 | chimbote
# Processing Record 20 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 21 of Set 9 | shumikha
# Processing Record 22 of Set 9 | mount gambier
# Processing Record 23 of Set 9 | tanout
# Processing Record 24 of Set 9 | waingapu
# Processing Record 25 of Set 9 | kayerkan
# Processing Record 26 of Set 9 | fethiye
# Processing Record 27 of Set 9 | bay roberts
# Processing Record 28 of Set 9 | tondano
# Processing Record 29 of Set 9 | yerbogachen
# Processing Record 30 of Set 9 | lang suan
# Processing Record 31 of Set 9 | hokitika
# Processing Record 32 of Set 9 | sobolevo
# Processing Record 33 of Set 9 | tautira
# Processing Record 34 of Set 9 | gunjur
# Processing Record 35 of Set 9 | plouzane
# Processing Record 36 of Set 9 | shaping
# Processing Record 37 of Set 9 | eirunepe
# Processing Record 38 of Set 9 | angoram
# Processing Record 39 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 9 | san carlos
# Processing Record 41 of Set 9 | alugan
# Processing Record 42 of Set 9 | darnah
# Processing Record 43 of Set 9 | kashan
# Processing Record 44 of Set 9 | kuito
# Processing Record 45 of Set 9 | kahului
# Processing Record 46 of Set 9 | cayenne
# Processing Record 47 of Set 9 | sola
# Processing Record 48 of Set 9 | erzin
# Processing Record 49 of Set 9 | ewo
# Processing Record 50 of Set 9 | banff
# Processing Record 1 of Set 10 | porto belo
# Processing Record 2 of Set 10 | birnin kebbi
# Processing Record 3 of Set 10 | xuddur
# Processing Record 4 of Set 10 | baruun-urt
# Processing Record 5 of Set 10 | naugarzan
# City not found. Skipping...
# Processing Record 6 of Set 10 | mumford
# Processing Record 7 of Set 10 | ewa beach
# Processing Record 8 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 9 of Set 10 | honiara
# Processing Record 10 of Set 10 | luderitz
# Processing Record 11 of Set 10 | bilma
# Processing Record 12 of Set 10 | itarema
# Processing Record 13 of Set 10 | biak
# Processing Record 14 of Set 10 | muravlenko
# Processing Record 15 of Set 10 | namatanai
# Processing Record 16 of Set 10 | bagu
# Processing Record 17 of Set 10 | tomball
# Processing Record 18 of Set 10 | zarand
# Processing Record 19 of Set 10 | acapulco
# Processing Record 20 of Set 10 | shenjiamen
# Processing Record 21 of Set 10 | kyzyl
# Processing Record 22 of Set 10 | anloga
# Processing Record 23 of Set 10 | shache
# Processing Record 24 of Set 10 | malakal
# Processing Record 25 of Set 10 | marrakesh
# Processing Record 26 of Set 10 | pokhara
# Processing Record 27 of Set 10 | pathein
# Processing Record 28 of Set 10 | iquique
# Processing Record 29 of Set 10 | kwinana
# Processing Record 30 of Set 10 | jizan
# Processing Record 31 of Set 10 | kamenka
# Processing Record 32 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 33 of Set 10 | tutoia
# Processing Record 34 of Set 10 | idil
# Processing Record 35 of Set 10 | oriximina
# Processing Record 36 of Set 10 | barabai
# Processing Record 37 of Set 10 | nizhnevartovsk
# Processing Record 38 of Set 10 | novoagansk
# Processing Record 39 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 40 of Set 10 | goya
# Processing Record 41 of Set 10 | shieli
# Processing Record 42 of Set 10 | dandong
# Processing Record 43 of Set 10 | hvolsvollur
# Processing Record 44 of Set 10 | gazipur
# Processing Record 45 of Set 10 | vanimo
# Processing Record 46 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 47 of Set 10 | tiznit
# Processing Record 48 of Set 10 | port-gentil
# Processing Record 49 of Set 10 | tromso
# Processing Record 50 of Set 10 | ballina
# Processing Record 1 of Set 11 | okhotsk
# Processing Record 2 of Set 11 | goderich
# Processing Record 3 of Set 11 | polyarnyy
# Processing Record 4 of Set 11 | yashkino
# Processing Record 5 of Set 11 | bialogard
# Processing Record 6 of Set 11 | tateyama
# Processing Record 7 of Set 11 | ayagoz
# Processing Record 8 of Set 11 | tungor
# Processing Record 9 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 10 of Set 11 | guangyuan
# Processing Record 11 of Set 11 | nadym
# Processing Record 12 of Set 11 | kenai
# Processing Record 13 of Set 11 | lakes entrance
# Processing Record 14 of Set 11 | baykit
# Processing Record 15 of Set 11 | corcoran
# Processing Record 16 of Set 11 | joshimath
# Processing Record 17 of Set 11 | altamira
# Processing Record 18 of Set 11 | shubarshi
# Processing Record 19 of Set 11 | datong
# Processing Record 20 of Set 11 | acuna
# City not found. Skipping...
# Processing Record 21 of Set 11 | lamu
# Processing Record 22 of Set 11 | xinzhou
# Processing Record 23 of Set 11 | san carlos del zulia
# Processing Record 24 of Set 11 | san andres
# Processing Record 25 of Set 11 | grants
# Processing Record 26 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 11 | businga
# Processing Record 28 of Set 11 | tuatapere
# Processing Record 29 of Set 11 | lazaro cardenas
# Processing Record 30 of Set 11 | amazar
# Processing Record 31 of Set 11 | zhezkazgan
# Processing Record 32 of Set 11 | nenjiang
# Processing Record 33 of Set 11 | manokwari
# Processing Record 34 of Set 11 | xining
# Processing Record 35 of Set 11 | banjarmasin
# Processing Record 36 of Set 11 | la ronge
# Processing Record 37 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 38 of Set 11 | aykhal
# Processing Record 39 of Set 11 | tual
# Processing Record 40 of Set 11 | wangou
# Processing Record 41 of Set 11 | saint-georges
# Processing Record 42 of Set 11 | fort nelson
# Processing Record 43 of Set 11 | mweka
# Processing Record 44 of Set 11 | pangody
# Processing Record 45 of Set 11 | rock sound
# Processing Record 46 of Set 11 | santiago de cao
# Processing Record 47 of Set 11 | eydhafushi
# Processing Record 48 of Set 11 | luwuk
# Processing Record 49 of Set 11 | gabu
# Processing Record 50 of Set 11 | los alamos
# Processing Record 1 of Set 12 | shinpokh
# Processing Record 2 of Set 12 | turayf
# Processing Record 3 of Set 12 | san patricio
# Processing Record 4 of Set 12 | zurrieq
# Processing Record 5 of Set 12 | ucluelet
# Processing Record 6 of Set 12 | boulder city
# Processing Record 7 of Set 12 | namibe
# Processing Record 8 of Set 12 | rio brilhante
# Processing Record 9 of Set 12 | severobaykalsk
# Processing Record 10 of Set 12 | annecy-le-vieux
# Processing Record 11 of Set 12 | luena
# Processing Record 12 of Set 12 | portland
# Processing Record 13 of Set 12 | codrington
# Processing Record 14 of Set 12 | puerto del rosario
# Processing Record 15 of Set 12 | mubende
# Processing Record 16 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 17 of Set 12 | cheremshan
# Processing Record 18 of Set 12 | suntar
# Processing Record 19 of Set 12 | port hedland
# Processing Record 20 of Set 12 | lufilufi
# Processing Record 21 of Set 12 | sandviken
# Processing Record 22 of Set 12 | bhainsdehi
# Processing Record 23 of Set 12 | maralal
# Processing Record 24 of Set 12 | colquechaca
# Processing Record 25 of Set 12 | ixtapa
# Processing Record 26 of Set 12 | vilhena
# Processing Record 27 of Set 12 | kobryn
# Processing Record 28 of Set 12 | new plymouth
# Processing Record 29 of Set 12 | tura
# Processing Record 30 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 12 | fuerte olimpo
# Processing Record 32 of Set 12 | lewisporte
# Processing Record 33 of Set 12 | umm lajj
# Processing Record 34 of Set 12 | flinders
# Processing Record 35 of Set 12 | leningradskiy
# Processing Record 36 of Set 12 | pahrump
# Processing Record 37 of Set 12 | taunggyi
# Processing Record 38 of Set 12 | mariani
# Processing Record 39 of Set 12 | alofi
# Processing Record 40 of Set 12 | nata
# Processing Record 41 of Set 12 | sendafa
# Processing Record 42 of Set 12 | kandrian
# Processing Record 43 of Set 12 | grand gaube
# Processing Record 44 of Set 12 | aizpute
# Processing Record 45 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 46 of Set 12 | arkhara
# Processing Record 47 of Set 12 | bakaly
# Processing Record 48 of Set 12 | lubao
# Processing Record 49 of Set 12 | beira
# Processing Record 50 of Set 12 | vikhorevka
# Processing Record 1 of Set 13 | concordia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Tasiilaq  65.6145  -37.6368     17.73        94         100
# 1     Chukhloma  58.7525   42.6825     22.06        95         100
# 2     Busselton -33.6500  115.3333     76.05        47          10
# 3  Puerto Ayora  -0.7393  -90.3518     73.06        83          70
# 4       Isangel -19.5500  169.2667     77.18        75          74
# 5      Cidreira -30.1811  -50.2056     82.78        71         100
# 6         Chuka  -0.3332   37.6459     68.95        77          94
# 7     Geraldton -28.7667  114.6000     73.81        78          40
# 8         Vaini -21.2000 -175.2000     80.58        78          43
# 9    Toora-Khem  52.4675   96.1100      7.21        97         100
#
#    Wind Speed Country                 Date
# 0        7.70      GL  2022-01-17 13:42:12
# 1        9.33      RU  2022-01-17 13:42:13
# 2       17.09      AU  2022-01-17 13:42:14
# 3        5.41      EC  2022-01-17 13:42:14
# 4        9.86      VU  2022-01-17 13:42:15
# 5        5.53      BR  2022-01-17 13:42:16
# 6        1.39      KE  2022-01-17 13:42:17
# 7       17.27      AU  2022-01-17 13:42:18
# 8       17.40      TO  2022-01-17 13:42:19
# 9        1.21      RU  2022-01-17 13:42:19

# %%
city_data_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
